# %%
import numpy as np
import pandas as pd
import re
from currency_conversion import convert_column

# %%
df = pd.read_csv("../dat/raw_data.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110155 entries, 0 to 110154
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   tconst                       110155 non-null  object
#  1   titleType                    110155 non-null  object
#  2   primaryTitle                 110155 non-null  object
#  3   originalTitle                110155 non-null  object
#  4   isAdult                      110155 non-null  int64
#  5   startYear                    110155 non-null  object
#  6   endYear                      110155 non-null  object
#  7   runtimeMinutes               110155 non-null  object
#  8   genres                       110155 non-null  object
#  9   averageRating                110155 non-null  float64
#  10  numVotes                     110155 non-null  int64
#  11  Budget                       28080 non-null   object
#  12  Gross US & Canada            18140 non-null   object
#  13  Opening weekend US & Canada  15542 non-null   object
#  14  Gross worldwide              37572 non-null   object
#  15  Rating                       58937 non-null   object
#  16  User reviews                 88915 non-null   object
#  17  Critic reviews               76877 non-null   object
#  18  directors                    110155 non-null  object
#  19  writers                      110155 non-null  object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 16.8+ MB
# /home/daniel/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (5,17) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df = convert_column(df, "Budget")

# %%
df = convert_column(df, "Gross US & Canada")

# %%
df = convert_column(df, "Opening weekend US & Canada")

# %%
df = convert_column(df, "Gross worldwide")

# %%
df
# Out:
#            tconst titleType                 primaryTitle  \
# 0       tt0000574     movie  The Story of the Kelly Gang
# 1       tt0001258     movie        The White Slave Trade
# 2       tt0001892     movie               Den sorte drøm
# 3       tt0002101     movie                    Cleopatra
# 4       tt0002130     movie              Dante's Inferno
# ...           ...       ...                          ...
# 110150  tt9914286     movie            Sokagin Çocuklari
# 110151  tt9914942     movie       Life Without Sara Amat
# 110152  tt9916190     movie                    Safeguard
# 110153  tt9916270     movie     Il talento del calabrone
# 110154  tt9916362     movie                        Coven
#
#                       originalTitle  isAdult startYear endYear runtimeMinutes  \
# 0       The Story of the Kelly Gang        0      1906      \N             70
# 1             Den hvide slavehandel        0      1910      \N             45
# 2                    Den sorte drøm        0      1911      \N             53
# 3                         Cleopatra        0      1912      \N            100
# 4                         L'Inferno        0      1911      \N             71
# ...                             ...      ...       ...     ...            ...
# 110150            Sokagin Çocuklari        0      2019      \N             98
# 110151   La vida sense la Sara Amat        0      2019      \N             74
# 110152                    Safeguard        0      2020      \N             90
# 110153     Il talento del calabrone        0      2020      \N             84
# 110154                     Akelarre        0      2020      \N             92
#
#                             genres  averageRating  numVotes     Budget  \
# 0       Action,Adventure,Biography            6.1       744    66037.0
# 1                            Drama            5.7       138        NaN
# 2                            Drama            5.9       221        NaN
# 3                    Drama,History            5.1       524  1294852.0
# 4          Adventure,Drama,Fantasy            7.0      2757        NaN
# ...                            ...            ...       ...        ...
# 110150                Drama,Family            7.6       218        NaN
# 110151                       Drama            6.9       137        NaN
# 110152   Action,Adventure,Thriller            3.5       227        NaN
# 110153                    Thriller            5.8      1279        NaN
# 110154               Drama,History            6.4      4271  3000382.0
#
#         Gross US & Canada  Opening weekend US & Canada  Gross worldwide  \
# 0                     NaN                          NaN              NaN
# 1                     NaN                          NaN              NaN
# 2                     NaN                          NaN              NaN
# 3                     NaN                          NaN              NaN
# 4                     NaN                          NaN              NaN
# ...                   ...                          ...              ...
# 110150                NaN                          NaN           3089.0
# 110151                NaN                          NaN          65215.0
# 110152                NaN                          NaN              NaN
# 110153                NaN                          NaN              NaN
# 110154                NaN                          NaN         342531.0
#
#            Rating User reviews Critic reviews                      directors  \
# 0       Not Rated         14.0            7.0                      nm0846879
# 1             NaN          4.0            NaN                      nm0088881
# 2             NaN          5.0            2.0                      nm0300487
# 3         Unrated         26.0            4.0                      nm0309130
# 4             NaN           35           12.0  nm0655824,nm0209738,nm0078205
# ...           ...          ...            ...                            ...
# 110150        NaN          NaN            NaN                      nm1832009
# 110151        NaN          NaN            NaN                      nm1716653
# 110152        NaN         82.0            NaN                      nm7308376
# 110153        NaN            9            7.0                      nm1480867
# 110154      TV-MA           36           28.0                      nm1893148
#
#                      writers
# 0                  nm0846879
# 1                         \N
# 2        nm0300487,nm2131092
# 3        nm0765026,nm0309130
# 4                  nm0019604
# ...                      ...
# 110150   nm1832009,nm1902682
# 110151   nm3678448,nm9361716
# 110152             nm7308376
# 110153  nm1480867,nm10538402
# 110154   nm1893148,nm3471432
#
# [110155 rows x 20 columns]
